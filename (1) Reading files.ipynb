# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
# atxt = [
#         'Acquisition_2000Q1.txt','Acquisition_2000Q2.txt','Acquisition_2000Q3.txt','Acquisition_2000Q4.txt',
#         'Acquisition_2001Q1.txt','Acquisition_2001Q2.txt','Acquisition_2001Q3.txt','Acquisition_2001Q4.txt',
#         'Acquisition_2002Q1.txt','Acquisition_2002Q2.txt','Acquisition_2002Q3.txt','Acquisition_2002Q4.txt',
#         'Acquisition_2003Q1.txt','Acquisition_2003Q2.txt','Acquisition_2003Q3.txt','Acquisition_2003Q4.txt',
#         'Acquisition_2004Q1.txt','Acquisition_2004Q2.txt','Acquisition_2004Q3.txt','Acquisition_2004Q4.txt',
#         'Acquisition_2005Q1.txt','Acquisition_2005Q2.txt','Acquisition_2005Q3.txt','Acquisition_2005Q4.txt',
#         'Acquisition_2006Q1.txt','Acquisition_2006Q2.txt','Acquisition_2006Q3.txt','Acquisition_2006Q4.txt',
#         'Acquisition_2007Q1.txt','Acquisition_2007Q2.txt','Acquisition_2007Q3.txt','Acquisition_2007Q4.txt',
#         'Acquisition_2008Q1.txt','Acquisition_2008Q2.txt','Acquisition_2008Q3.txt','Acquisition_2008Q4.txt',
#         'Acquisition_2009Q1.txt','Acquisition_2009Q2.txt','Acquisition_2009Q3.txt','Acquisition_2009Q4.txt',
#         'Acquisition_2010Q1.txt','Acquisition_2010Q2.txt','Acquisition_2010Q3.txt','Acquisition_2010Q4.txt',
#         'Acquisition_2011Q1.txt','Acquisition_2011Q2.txt','Acquisition_2011Q3.txt','Acquisition_2011Q4.txt',
#         'Acquisition_2012Q1.txt','Acquisition_2012Q2.txt','Acquisition_2012Q3.txt','Acquisition_2012Q4.txt',
#         'Acquisition_2013Q1.txt','Acquisition_2013Q2.txt','Acquisition_2013Q3.txt','Acquisition_2013Q4.txt',
#         'Acquisition_2014Q1.txt','Acquisition_2014Q2.txt','Acquisition_2014Q3.txt','Acquisition_2014Q4.txt',
#         'Acquisition_2015Q1.txt','Acquisition_2015Q2.txt','Acquisition_2015Q3.txt','Acquisition_2015Q4.txt',
#         'Acquisition_2016Q1.txt','Acquisition_2016Q2.txt','Acquisition_2016Q3.txt','Acquisition_2016Q4.txt',
#         'Acquisition_2017Q1.txt','Acquisition_2017Q2.txt','Acquisition_2017Q3.txt'
#         ]

# acsv = [
#         'Acquisition_2000Q1.csv','Acquisition_2000Q2.csv','Acquisition_2000Q3.csv','Acquisition_2000Q4.csv',
#         'Acquisition_2001Q1.csv','Acquisition_2001Q2.csv','Acquisition_2001Q3.csv','Acquisition_2001Q4.csv',
#         'Acquisition_2002Q1.csv','Acquisition_2002Q2.csv','Acquisition_2002Q3.csv','Acquisition_2002Q4.csv',
#         'Acquisition_2003Q1.csv','Acquisition_2003Q2.csv','Acquisition_2003Q3.csv','Acquisition_2003Q4.csv',
#         'Acquisition_2004Q1.csv','Acquisition_2004Q2.csv','Acquisition_2004Q3.csv','Acquisition_2004Q4.csv',
#         'Acquisition_2005Q1.csv','Acquisition_2005Q2.csv','Acquisition_2005Q3.csv','Acquisition_2005Q4.csv',
#         'Acquisition_2006Q1.csv','Acquisition_2006Q2.csv','Acquisition_2006Q3.csv','Acquisition_2006Q4.csv',
#         'Acquisition_2007Q1.csv','Acquisition_2007Q2.csv','Acquisition_2007Q3.csv','Acquisition_2007Q4.csv',
#         'Acquisition_2008Q1.csv','Acquisition_2008Q2.csv','Acquisition_2008Q3.csv','Acquisition_2008Q4.csv',
        'Performance_2002Q1.csv','Performance_2002Q2.csv','Performance_2002Q3.csv','Performance_2002Q4.csv',
        'Performance_2003Q1.csv','Performance_2003Q2.csv','Performance_2003Q3.csv','Performance_2003Q4.csv',
        'Performance_2004Q1.csv','Performance_2004Q2.csv','Performance_2004Q3.csv','Performance_2004Q4.csv',
        'Performance_2005Q1.csv','Performance_2005Q2.csv','Performance_2005Q3.csv','Performance_2005Q4.csv',
        'Performance_2006Q1.csv','Performance_2006Q2.csv','Performance_2006Q3.csv','Performance_2006Q4.csv',
        'Performance_2007Q1.csv','Performance_2007Q2.csv','Performance_2007Q3.csv','Performance_2007Q4.csv',
        'Performance_2008Q1.csv','Performance_2008Q2.csv','Performance_2008Q3.csv','Performance_2008Q4.csv',
        'Performance_2009Q1.csv','Performance_2009Q2.csv','Performance_2009Q3.csv','Performance_2009Q4.csv',
        'Performance_2010Q1.csv','Performance_2010Q2.csv','Performance_2010Q3.csv','Performance_2010Q4.csv',
        'Performance_2011Q1.csv','Performance_2011Q2.csv','Performance_2011Q3.csv','Performance_2011Q4.csv',
        'Performance_2012Q1.csv','Performance_2012Q2.csv','Performance_2012Q3.csv','Performance_2012Q4.csv',
        'Performance_2013Q1.csv','Performance_2013Q2.csv','Performance_2013Q3.csv','Performance_2013Q4.csv',
        'Performance_2014Q1.csv','Performance_2014Q2.csv','Performance_2014Q3.csv','Performance_2014Q4.csv',
        'Performance_2015Q1.csv','Performance_2015Q2.csv','Performance_2015Q3.csv','Performance_2015Q4.csv',
        'Performance_2016Q1.csv','Performance_2016Q2.csv','Performance_2016Q3.csv','Performance_2016Q4.csv',
        'Performance_2017Q1.csv','Performance_2017Q2.csv','Performance_2017Q3.csv'
        ]

# %%
# mcsv = [
#         'Merged_2000Q1.csv','Merged_2000Q2.csv','Merged_2000Q3.csv','Merged_2000Q4.csv',
#         'Merged_2001Q1.csv','Merged_2001Q2.csv','Merged_2001Q3.csv','Merged_2001Q4.csv',
#         'Merged_2002Q1.csv','Merged_2002Q2.csv','Merged_2002Q3.csv','Merged_2002Q4.csv',
#         'Merged_2003Q1.csv','Merged_2003Q2.csv','Merged_2003Q3.csv','Merged_2003Q4.csv',
#         'Merged_2004Q1.csv','Merged_2004Q2.csv','Merged_2004Q3.csv','Merged_2004Q4.csv',
#         'Merged_2005Q1.csv','Merged_2005Q2.csv','Merged_2005Q3.csv','Merged_2005Q4.csv',
#         'Merged_2006Q1.csv','Merged_2006Q2.csv','Merged_2006Q3.csv','Merged_2006Q4.csv',
#         'Merged_2007Q1.csv','Merged_2007Q2.csv','Merged_2007Q3.csv','Merged_2007Q4.csv',
#         'Merged_2008Q1.csv','Merged_2008Q2.csv','Merged_2008Q3.csv','Merged_2008Q4.csv',
#         'Merged_2009Q1.csv','Merged_2009Q2.csv','Merged_2009Q3.csv','Merged_2009Q4.csv',
#         'Merged_2010Q1.csv','Merged_2010Q2.csv','Merged_2010Q3.csv','Merged_2010Q4.csv',
#         'Merged_2011Q1.csv','Merged_2011Q2.csv','Merged_2011Q3.csv','Merged_2011Q4.csv',
#         'Merged_2012Q1.csv','Merged_2012Q2.csv','Merged_2012Q3.csv','Merged_2012Q4.csv',
#         'Merged_2013Q1.csv','Merged_2013Q2.csv','Merged_2013Q3.csv','Merged_2013Q4.csv',
#         'Merged_2014Q1.csv','Merged_2014Q2.csv','Merged_2014Q3.csv','Merged_2014Q4.csv',
#         'Merged_2015Q1.csv','Merged_2015Q2.csv','Merged_2015Q3.csv','Merged_2015Q4.csv',
#         'Merged_2016Q1.csv','Merged_2016Q2.csv','Merged_2016Q3.csv','Merged_2016Q4.csv',
#         'Merged_2017Q1.csv','Merged_2017Q2.csv','Merged_2017Q3.csv'
#         ]

# %%
# Acquisitions_Variables = ["LOAN_ID","ORIG_CHN","Seller.Name","ORIG_RT","ORIG_AMT","ORIG_TRM","ORIG_DTE","FRST_DTE",
#                           "OLTV","OCLTV","NUM_BO","DTI","CSCORE_B","FTHB_FLG","PURPOSE","PROP_TYP","NUM_UNIT",
#                           "OCC_STAT","STATE","ZIP_3","MI_PCT","Product.Type","CSCORE_C","MI_TYPE","RELOCATION_FLG"]

# %%
Performance_Variables = ["LOAN_ID","Monthly.Rpt.Prd","Servicer.Name","LAST_RT","LAST_UPB","Loan.Age",
                         "Months.To.Legal.Mat","Adj.Month.To.Mat","Maturity.Date","MSA","Delq.Status",
                         "MOD_FLAG","Zero.Bal.Code","ZB_DTE","LPI_DTE","FCC_DTE","DISP_DT","FCC_COST",
                         "PP_COST","AR_COST","IE_COST","TAX_COST","NS_PROCS","CE_PROCS","RMW_PROCS",
                         "O_PROCS","NON_INT_UPB","PRIN_FORG_UPB_FHFA","REPCH_FLAG","PRIN_FORG_UPB_OTH","TRANSFER_FLG"]

# %%
for j in range(len(ptxt)):
#     a = pd.read_csv(atxt[j],header=None,sep='|',names=Acquisitions_Variables)
    p = pd.read_csv(ptxt[j],header=None,sep='|',names=Performance_Variables)
    LAST = Performance_Variables[1:10] + Performance_Variables[12:28] + Performance_Variables[29:30]
    MAX = Performance_Variables[10:12] + Performance_Variables[28:29] + Performance_Variables[30:]
    DELI = Performance_Variables[10]
    flag_mapping = {'N':0, 'Y':1}
    for i in MAX:
        p[i] = p[i].map(flag_mapping)
    p[DELI] = pd.to_numeric(p[DELI].replace('X','0'))
    grouped = p.groupby('LOAN_ID')
    P1 = grouped[LAST].last()
    P2 = grouped[MAX].max()
    P = pd.concat([P1,P2],axis=1)
    P = P[Performance_Variables[1:]]
#     pacq = pd.merge(a,P,how='inner',on="LOAN_ID")
#     pacq.to_csv(mcsv[j])
    P.to_csv(ptxt[j])

# %%
ptxt
# Out:
# ['Performance_2000Q1.txt',
#  'Performance_2000Q2.txt',
#  'Performance_2000Q3.txt',
#  'Performance_2000Q4.txt',
#  'Performance_2001Q1.txt',
#  'Performance_2001Q2.txt',
#  'Performance_2001Q3.txt',
#  'Performance_2001Q4.txt',
#  'Performance_2002Q1.txt',
#  'Performance_2002Q2.txt',
#  'Performance_2002Q3.txt',
#  'Performance_2002Q4.txt',
#  'Performance_2003Q1.txt',
#  'Performance_2003Q2.txt',
#  'Performance_2003Q3.txt',
#  'Performance_2003Q4.txt',
#  'Performance_2004Q1.txt',
#  'Performance_2004Q2.txt',
#  'Performance_2004Q3.txt',
#  'Performance_2004Q4.txt',
#  'Performance_2005Q1.txt',
#  'Performance_2005Q2.txt',
#  'Performance_2005Q3.txt',
#  'Performance_2005Q4.txt',
#  'Performance_2006Q1.txt',
#  'Performance_2006Q2.txt',
#  'Performance_2006Q3.txt',
#  'Performance_2006Q4.txt',
#  'Performance_2007Q1.txt',
#  'Performance_2007Q2.txt',
#  'Performance_2007Q3.txt',
#  'Performance_2007Q4.txt',
#  'Performance_2008Q1.txt',
#  'Performance_2008Q2.txt',
# ...
